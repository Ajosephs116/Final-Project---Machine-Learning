# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb

# %%
# result variable is referenced in player 1. If result = 1, player 1 won.
# FNL.1>FNL.2  Final Number of Games Won by Player 1 (Numeric-Integer)

# %%
AusOpen = pd.read_csv("AusOpen-women-2013.csv")
AusOpen.columns
# Out:
# Index(['Player1', 'Player2', 'Round', 'Result', 'FNL1', 'FNL2', 'FSP.1',
#        'FSW.1', 'SSP.1', 'SSW.1', 'ACE.1', 'DBF.1', 'WNR.1', 'UFE.1', 'BPC.1',
#        'BPW.1', 'NPA.1', 'NPW.1', 'TPW.1', 'ST1.1', 'ST2.1', 'ST3.1', 'ST4.1',
#        'ST5.1', 'FSP.2', 'FSW.2', 'SSP.2', 'SSW.2', 'ACE.2', 'DBF.2', 'WNR.2',
#        'UFE.2', 'BPC.2', 'BPW.2', 'NPA.2', 'NPW.2', 'TPW.2', 'ST1.2', 'ST2.2',
#        'ST3.2', 'ST4.2', 'ST5.2'],
#       dtype='object')

# %%
FrOpen=pd.read_csv("FrenchOpen-women-2013.csv")
FrOpen.columns
# Out:
# Index(['Player1', 'Player2', 'Round', 'Result', 'FNL.1', 'FNL.2', 'FSP.1',
#        'FSW.1', 'SSP.1', 'SSW.1', 'ACE.1', 'DBF.1', 'WNR.1', 'UFE.1', 'BPC.1',
#        'BPW.1', 'NPA.1', 'NPW.1', 'TPW.1', 'ST1.1', 'ST2.1', 'ST3.1', 'ST4.1',
#        'ST5.1', 'FSP.2', 'FSW.2', 'SSP.2', 'SSW.2', 'ACE.2', 'DBF.2', 'WNR.2',
#        'UFE.2', 'BPC.2', 'BPW.2', 'NPA.2', 'NPW.2', 'TPW.2', 'ST1.2', 'ST2.2',
#        'ST3.2', 'ST4.2', 'ST5.2'],
#       dtype='object')

# %%
UsOpen = pd.read_csv("USOpen-women-2013.csv")
UsOpen.columns
# Out:
# Index(['Player 1', 'Player 2', 'ROUND', 'Result', 'FNL.1', 'FNL.2', 'FSP.1',
#        'FSW.1', 'SSP.1', 'SSW.1', 'ACE.1', 'DBF.1', 'WNR.1', 'UFE.1', 'BPC.1',
#        'BPW.1', 'NPA.1', 'NPW.1', 'TPW.1', 'ST1.1', 'ST2.1', 'ST3.1', 'ST4.1',
#        'ST5.1', 'FSP.2', 'FSW.2', 'SSP.2', 'SSW.2', 'ACE.2', 'DBF.2', 'WNR.2',
#        'UFE.2', 'BPC.2', 'BPW.2', 'NPA.2', 'NPW.2', 'TPW.2', 'ST2.1.1',
#        'ST2.2', 'ST3.2', 'ST4.2', 'ST5.2'],
#       dtype='object')

# %%
Wbd = pd.read_csv("Wimbledon-women-2013.csv")
Wbd.columns
# Out:
# Index(['Player1', 'Player2', 'Round', 'Result', 'FNL.1', 'FNL.2', 'FSP.1',
#        'FSW.1', 'SSP.1', 'SSW.1', 'ACE.1', 'DBF.1', 'WNR.1', 'UFE.1', 'BPC.1',
#        'BPW.1', 'NPA.1', 'NPW.1', 'TPW.1', 'ST1.1', 'ST2.1', 'ST3.1', 'ST4.1',
#        'ST5.1', 'FSP.2', 'FSW.2', 'SSP.2', 'SSW.2', 'ACE.2', 'DBF.2', 'WNR.2',
#        'UFE.2', 'BPC.2', 'BPW.2', 'NPA.2', 'NPW.2', 'TPW.2', 'ST1.1.1',
#        'ST2.2', 'ST3.2', 'ST4.2', 'ST5.2'],
#       dtype='object')

# %%
UsOpen.describe
UsOpen.head(20)
# Out:
#             Player 1      Player 2  ROUND  Result  FNL.1  FNL.2  FSP.1  FSW.1  \
# 0         S Williams    V Azarenka      7       1      2      1     57     44
# 1         F Pennetta    V Azarenka      6       0      0      2     44     12
# 2         S Williams          N Li      6       1      2      0     63     26
# 3            R Vinci    F Pennetta      5       0      0      2     60     21
# 4       D Hantuchova    V Azarenka      5       0      0      2     58     14
# 5         E Makarova          N Li      5       0      1      2     60     40
# 6         A Ivanovic    V Azarenka      4       0      1      2     55     26
# 7            A Riske  D Hantuchova      4       0      1      2     69     37
# 8            S Halep    F Pennetta      4       0      0      2     75     22
# 9           C Giorgi       R Vinci      4       0      0      2     54     18
# 10        S Williams    S Stephens      4       1      2      0     62     26
# ...

# %%
UsOpen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 42 columns):
# Player 1    76 non-null object
# Player 2    76 non-null object
# ROUND       76 non-null int64
# Result      76 non-null int64
# FNL.1       76 non-null int64
# FNL.2       76 non-null int64
# FSP.1       76 non-null int64
# FSW.1       76 non-null int64
# SSP.1       76 non-null int64
# SSW.1       76 non-null int64
# ACE.1       76 non-null int64
# DBF.1       76 non-null int64
# WNR.1       76 non-null int64
# UFE.1       76 non-null int64
# BPC.1       76 non-null int64
# BPW.1       76 non-null int64
# NPA.1       74 non-null float64
# NPW.1       75 non-null float64
# TPW.1       0 non-null float64
# ST1.1       76 non-null int64
# ST2.1       76 non-null int64
# ST3.1       20 non-null float64
# ST4.1       0 non-null float64
# ST5.1       0 non-null float64
# FSP.2       76 non-null int64
# FSW.2       76 non-null int64
# SSP.2       76 non-null int64
# ...

# %%
#remove columns that won't be used
UsOpen_reduced = UsOpen.drop(columns=['ST3.1','ST4.1','ST5.1','ST3.2','ST4.2','ST5.2','TPW.1','TPW.2','FNL.1','FNL.2', 'Player 1','Player 2'])

# %%
#drop rows with missing values (na)
UsOpen_reduced = UsOpen_reduced.dropna()

# %% [markdown]
# ## DELETE

# %%
##UsOpen_reduced = UsOpen_reduced.drop(columns=['Player 1','Player 2'])

# %%
## separate the columns into dependent and independent variables (or features and labels)
y = UsOpen_reduced['Result']
# Keep everything else
X = UsOpen_reduced.drop(columns=['Result']) 

#NOTE: The column Result = Result of the match (0/1) - Referenced on Player 1. Result = 1, if Player 1 wins (FNL.1>FNL.2)

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

# Split dataset into two sets (training set and test set)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # 70% training and 30% test

# By specifying the train_size as 0.75, or the test_size as 0.3, we aim to put 75% of the data into our training set,
# and the rest of the data into the test set 

# print data from each group
print ("X_train: ", X_train)
print ("y_train: ", y_train)
print("X_test: ", X_test)
print ("y_test: ", y_test)
# Out:
# X_train:      ROUND  FSP.1  FSW.1  SSP.1  SSW.1  ACE.1  DBF.1  WNR.1  UFE.1  BPC.1  \
# 65      1     68     22     42      6      3      4     11     17      0
# 6       4     55     26     45     18      3      8     41     42     13
# 62      1     46     15     54      7      1      6     16     19      8
# 46      2     47     14     53     10      2      5     18     37      2
# 22      3     55     14     45      6      0      1     12     34      7
# 67      1     64     28     36     14      1      2      8     21      3
# 47      2     59     28     41     17      8      2     23     21      2
# 66      1     65     43     35     18      1      2     15     37     15
# 59      1     54     18     46     16      3      0     35     30     14
# 56      1     63     38     37     18      2      2     25     55     10
# 49      1     73     47     27     11      3      4     29     29     11
# 12      4     78     54     22      9      2      1     45     47     19
# ...

# %%
# It randomly picks data to form the training and test set, 
# which is usually a desirable feature in real-world applications to avoid possible artifacts existing 
# in the data preparation process

# After splitting, you will train the model on the training set and perform predictions on the test set.

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

## Create a random forest Classifier.
#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)
  #By convention, clf means 'Classifier'
    
    
#Train the model using the training sets y_pred=clf.predict(X_test)
# Train the Classifier to take the training features and learn how they relate to the training y
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred=clf.predict(X_test)

#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9130434782608695

# %%
s1 = pd.Series(clf.feature_importances_)
s2 = pd.Series(X.columns)
feat_imp = pd.concat([s1, s2], axis=1).reset_index()

# %%
feat_imp
# Out:
#     index         0        1
# 0       0  0.004712    ROUND
# 1       1  0.012423    FSP.1
# 2       2  0.032900    FSW.1
# 3       3  0.012641    SSP.1
# 4       4  0.021266    SSW.1
# 5       5  0.019014    ACE.1
# 6       6  0.010069    DBF.1
# 7       7  0.021939    WNR.1
# 8       8  0.033308    UFE.1
# 9       9  0.026234    BPC.1
# 10     10  0.063790    BPW.1
# 11     11  0.025512    NPA.1
# 12     12  0.023162    NPW.1
# 13     13  0.079977    ST1.1
# 14     14  0.062968    ST2.1
# 15     15  0.005424    FSP.2
# 16     16  0.032951    FSW.2
# 17     17  0.004016    SSP.2
# 18     18  0.027654    SSW.2
# 19     19  0.003460    ACE.2
# 20     20  0.009315    DBF.2
# 21     21  0.012098    WNR.2
# 22     22  0.020467    UFE.2
# 23     23  0.034484    BPC.2
# 24     24  0.112251    BPW.2
# 25     25  0.018679    NPA.2
# 26     26  0.024789    NPW.2
# 27     27  0.140835  ST2.1.1
# 28     28  0.103662    ST2.2

# %%
type(feat_imp)
# Out:
# pandas.core.frame.DataFrame

# %%
#sort dataframe
feat_imp.sort_values(0, ascending=False)
# ST2.1 - Set 2 Result for Player 1
# BPW.2 - Break Points Won by Players 2
# ST2.2 - set 2 Result by Player 2
# Out:
#     index         0        1
# 27     27  0.140835  ST2.1.1
# 24     24  0.112251    BPW.2
# 28     28  0.103662    ST2.2
# 13     13  0.079977    ST1.1
# 10     10  0.063790    BPW.1
# 14     14  0.062968    ST2.1
# 23     23  0.034484    BPC.2
# 8       8  0.033308    UFE.1
# 16     16  0.032951    FSW.2
# 2       2  0.032900    FSW.1
# 18     18  0.027654    SSW.2
# 9       9  0.026234    BPC.1
# 11     11  0.025512    NPA.1
# 26     26  0.024789    NPW.2
# 12     12  0.023162    NPW.1
# 7       7  0.021939    WNR.1
# 4       4  0.021266    SSW.1
# 22     22  0.020467    UFE.2
# 5       5  0.019014    ACE.1
# 25     25  0.018679    NPA.2
# 3       3  0.012641    SSP.1
# 1       1  0.012423    FSP.1
# 21     21  0.012098    WNR.2
# 6       6  0.010069    DBF.1
# 20     20  0.009315    DBF.2
# 15     15  0.005424    FSP.2
# 0       0  0.004712    ROUND
# 17     17  0.004016    SSP.2
# 19     19  0.003460    ACE.2

# %%
feature_imp = pd.Series(clf.feature_importances_,index=iris.feature_names).sort_values(ascending=False)


import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Creating a bar plot
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()

# %%
UsOpen.max()
# Out:
# Player 1    V Williams
# Player 2    Y Shvedova
# ROUND                7
# Result               1
# FNL.1                2
# FNL.2                2
# FSP.1               80
# FSW.1               54
# SSP.1               59
# SSW.1               27
# ACE.1                9
# DBF.1               10
# WNR.1               49
# UFE.1               60
# BPC.1               25
# BPW.1                8
# NPA.1               38
# NPW.1               62
# TPW.1             None
# ST1.1                7
# ST2.1                7
# ST3.1                7
# ST4.1             None
# ST5.1             None
# FSP.2               93
# FSW.2               51
# SSP.2               58
# SSW.2               26
# ACE.2               15
# DBF.2               10
# WNR.2               46
# UFE.2               58
# BPC.2               19
# BPW.2                9
# NPA.2               35
# NPW.2               34
# TPW.2             None
# ST2.1.1              7
# ST2.2                7
# ST3.2                7
# ...

# %%
plt.matshow(UsOpen.corr())
plt.show()

# %%
pd.scatter_matrix(UsOpen, alpha = 0.3, figsize = (14,8), diagonal = 'kde')
# Out:
# /Users/pcr_23/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-25e0e7ed733c> in <module>
# ----> 1 pd.scatter_matrix(UsOpen, alpha = 0.3, figsize = (14,8), diagonal = 'kde')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#      54         """
#      55         warnings.warn(warning_msg, klass, stacklevel=stacklevel)
# ---> 56         return alternative(*args, **kwargs)
#      57
#      58     # Since we are using Substitution to create the required docstring,
#
# ...

# %%
sns.pairplot(dataframe)

# %%
import seaborn as sns

f, ax = pl.subplots(figsize=(10, 8))
corr = dataframe.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)

# %% [markdown]
# ## Reference Links

# %%
#https://archive.ics.uci.edu/ml/datasets/Tennis+Major+Tournament+Match+Statistics

#https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
